# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/eval15/low/780.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/eval15/low/778.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/eval15/low/493.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/eval15/low/669.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/eval15/low/547.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/eval15/low/55.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/eval15/low/1.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/eval15/low/748.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/eval15/low/22.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/eval15/low/146.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/eval15/low/179.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/eval15/low/665.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/eval15/low/23.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/eval15/low/111.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/eval15/low/79.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/eval15/high/780.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/eval15/high/778.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/eval15/high/493.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/eval15/high/669.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/eval15/high/547.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/eval15/high/55.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/eval15/high/1.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/eval15/high/748.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/eval15/high/22.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/eval15/high/146.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/eval15/high/179.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/eval15/high/665.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/eval15/high/23.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/eval15/high/111.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/eval15/high/79.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/641.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/173.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/491.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/718.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/709.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/248.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/94.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/480.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/236.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/771.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/675.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/48.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/677.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/761.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/655.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/227.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/762.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/726.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/238.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/61.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/222.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/330.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/511.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/579.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/231.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/645.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/621.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/35.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/232.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/142.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/104.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/543.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/737.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/70.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/162.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/517.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/634.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/186.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/73.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/92.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/542.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/766.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/261.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/167.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/628.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/506.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/562.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/681.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/204.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/646.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/75.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/744.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/538.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/651.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/89.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/752.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/550.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/615.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/605.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/213.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/505.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/114.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/185.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/240.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/344.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/759.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/176.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/660.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/727.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/95.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/97.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/124.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/119.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/654.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/100.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/211.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/500.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/76.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/193.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/608.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/191.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/528.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/623.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/642.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/138.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/629.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/225.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/561.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/588.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/492.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/43.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/229.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/129.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/580.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/171.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/682.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/145.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/40.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/209.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/575.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/33.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/126.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/147.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/688.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/468.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/9.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/604.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/102.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/254.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/658.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/647.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/689.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/233.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/200.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/743.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/713.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/546.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/56.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/515.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/578.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/116.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/555.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/533.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/488.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/80.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/698.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/130.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/592.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/586.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/522.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/50.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/607.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/779.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/199.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/112.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/763.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/788.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/501.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/723.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/747.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/552.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/775.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/93.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/150.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/774.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/113.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/741.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/59.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/674.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/785.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/169.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/529.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/194.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/136.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/198.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/724.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/683.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/640.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/14.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/784.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/576.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/574.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/701.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/484.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/39.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/610.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/132.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/781.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/715.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/549.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/777.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/696.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/609.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/107.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/262.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/215.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/769.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/614.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/471.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/83.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/597.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/473.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/587.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/770.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/731.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/691.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/38.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/151.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/2.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/530.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/702.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/10.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/598.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/82.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/460.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/242.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/251.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/174.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/250.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/131.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/36.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/157.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/143.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/221.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/746.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/570.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/700.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/152.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/137.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/556.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/81.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/239.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/58.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/661.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/483.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/764.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/732.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/122.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/639.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/684.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/712.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/735.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/734.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/722.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/187.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/106.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/585.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/117.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/220.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/617.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/667.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/244.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/263.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/650.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/594.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/680.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/572.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/18.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/63.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/534.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/745.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/264.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/21.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/495.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/12.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/739.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/514.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/616.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/720.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/98.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/524.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/127.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/666.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/553.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/219.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/184.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/782.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/757.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/627.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/751.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/28.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/490.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/464.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/202.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/247.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/758.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/469.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/476.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/481.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/559.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/625.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/67.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/96.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/243.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/502.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/690.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/733.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/159.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/662.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/563.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/551.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/685.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/554.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/596.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/246.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/195.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/105.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/479.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/612.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/125.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/121.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/216.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/69.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/154.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/637.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/267.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/663.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/241.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/188.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/716.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/86.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/776.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/258.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/77.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/498.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/265.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/638.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/103.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/144.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/472.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/695.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/644.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/540.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/109.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/496.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/714.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/697.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/567.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/526.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/527.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/648.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/595.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/573.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/74.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/653.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/525.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/120.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/630.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/118.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/772.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/670.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/17.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/53.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/486.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/196.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/626.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/571.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/160.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/671.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/140.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/620.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/736.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/52.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/5.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/139.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/172.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/64.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/719.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/16.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/545.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/725.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/328.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/643.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/760.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/203.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/489.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/45.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/24.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/548.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/88.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/649.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/624.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/115.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/249.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/128.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/668.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/583.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/710.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/6.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/87.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/686.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/787.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/51.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/703.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/728.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/591.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/101.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/606.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/717.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/135.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/482.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/740.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/512.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/123.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/91.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/504.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/230.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/738.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/478.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/44.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/189.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/541.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/601.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/730.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/68.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/180.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/46.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/508.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/499.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/711.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/664.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/470.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/57.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/84.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/475.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/564.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/687.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/15.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/210.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/252.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/531.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/507.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/704.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/565.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/679.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/523.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/183.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/678.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/450.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/485.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/708.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/569.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/622.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/537.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/783.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/60.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/235.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/99.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/765.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/593.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/676.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/228.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/27.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/237.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/692.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/474.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/201.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/539.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/773.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/78.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/212.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/47.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/786.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/207.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/149.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/487.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/13.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/535.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/260.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/253.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/206.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/789.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/557.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/613.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/600.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/342.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/721.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/694.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/590.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/566.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/259.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/25.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/54.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/558.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/611.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/62.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/699.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/750.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/141.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/693.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/532.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/560.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/110.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/544.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/26.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/568.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/633.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/729.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/257.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/477.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/42.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/175.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/494.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/659.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/low/497.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/high/641.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/high/173.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/high/491.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/high/718.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/high/709.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/high/248.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/high/94.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/high/480.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/high/236.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/high/771.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/high/675.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/high/48.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/high/677.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/high/761.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/high/655.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/high/227.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/high/762.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/high/726.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/high/238.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/high/61.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/high/222.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/high/330.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/high/511.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/high/579.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/high/231.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/high/645.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/high/621.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/high/35.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/high/232.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/high/142.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/high/104.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/high/543.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/high/737.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/high/70.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/high/162.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/high/517.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/high/634.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/high/186.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/high/73.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/high/92.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/high/542.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/high/766.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/high/261.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/high/167.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/high/628.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/high/506.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/high/562.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/high/681.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/high/204.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/high/646.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/high/75.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/high/744.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/high/538.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/high/651.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/high/89.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/high/752.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/high/550.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/high/615.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/high/605.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/high/213.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/high/505.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/high/114.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/high/185.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/high/240.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/high/344.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/high/759.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/high/176.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/high/660.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/high/727.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/high/95.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/high/97.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/high/124.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/high/119.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/high/654.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/high/100.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/high/211.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/high/500.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/high/76.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/high/193.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/high/608.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/high/191.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/high/528.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/high/623.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/high/642.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/our485/high/138.png
# ...
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00059.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00502.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00124.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00214.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00032.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00602.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00345.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00100.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00005.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00669.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00522.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00551.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00278.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00546.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00560.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00077.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00002.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00597.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00492.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00274.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00644.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00581.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00072.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00363.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00493.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00302.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00358.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00150.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00207.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00647.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00510.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00520.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00586.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00422.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00131.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00659.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00459.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00467.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00030.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00636.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00511.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00284.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00301.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00662.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00266.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00664.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00324.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00553.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00228.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00536.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00476.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00052.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00661.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00475.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00227.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00231.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00178.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00528.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00129.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00288.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00544.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00066.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00263.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00253.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00675.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00113.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00407.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00571.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00332.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00483.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00419.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00401.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00557.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00161.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00323.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00386.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00572.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00180.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00342.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00629.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00671.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00441.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00410.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00073.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00397.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00244.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00377.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00211.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00292.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00496.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00303.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00021.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00451.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00403.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00552.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00427.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00272.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00264.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00612.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00514.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00550.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00334.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00603.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00040.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00307.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00025.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00601.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00539.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00308.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00626.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00487.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00584.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00402.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00155.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00495.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00171.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00689.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00172.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00149.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00576.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00431.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00310.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00201.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00580.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00655.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00219.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00471.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00328.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00344.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00117.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00337.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00650.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00012.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00110.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00183.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00360.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00265.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00220.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00037.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00098.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00374.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00028.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00643.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00577.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00405.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00213.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00588.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00240.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00078.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00512.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00375.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00281.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00637.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00389.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00247.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00320.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00616.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00215.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00343.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00027.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00314.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00362.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00501.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00453.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00127.png
# /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2/Real_captured/Train/Normal/normal00613.png

# %%
import numpy as np
import cv2
import glob
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import os
import imageio.v2 as imageio

# Check Kaggle input paths
print("Available input paths (first 10):")
count = 0
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
        count += 1
        if count >= 10:
            break
    if count >= 10:
        break
print(f"... and {sum(len(f) for _, _, f in os.walk('/kaggle/input')) - 10} more files")

# Paths for original LOL and LOL-v2 datasets
#lol_base = '/kaggle/input/loldataset/LOLdataset'
lol_base = '/kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset'
#lolv2_base = '/kaggle/input/lol-v2-dataset/LOL-v2'
lolv2_base = '/kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2'

# helper function to load images from a directory
def load_images_from_folder(folder, max_files=None):
    images = []
    files = sorted(glob.glob(os.path.join(folder, "*.png")))
    if max_files:
        files = files[:max_files]
    for file in files:
        try:
            image = imageio.imread(file)
            images.append(image)
        except Exception as e:
            print(f"Error loading {file}: {e}")
    return np.array(images)

# === ORIGINAL LOL DATASET ===
if os.path.exists(lol_base):
    print(f"Original LOL dataset found at {lol_base}")
    train_high_path = os.path.join(lol_base, 'our485/high')
    train_low_path = os.path.join(lol_base, 'our485/high')
    val_high_path = os.path.join(lol_base, 'eval15/high')
    val_low_path = os.path.join(lol_base, 'eval15/low')

    # Load training and validation images
    high_images = load_images_from_folder(train_high_path)
    low_images = load_images_from_folder(train_low_path)
    high_val = load_images_from_folder(val_high_path)
    low_val = load_images_from_folder(val_low_path)

    print(f"LOL Dataset - Training samples loaded: {len(high_images)}")
    print(f"LOL Dataset - Validation samples loaded: {len(high_val)}")
else:
    print("Original LOL dataset not found.")
real_train_low = []
real_train_normal = []
# === LOL-V2 DATASET ===
if os.path.exists(lolv2_base):
    print(f"LOL-V2 dataset found at {lolv2_base}")

    def get_v2_paths(base_type='Real_captured', split='Train'):
        low_path = os.path.join(lolv2_base, base_type, split, 'Low')
        normal_path = os.path.join(lolv2_base, base_type, split, 'Normal')
        return low_path, normal_path

    # Load LOL-V2 Real_captured training data
    real_low_train_path, real_normal_train_path = get_v2_paths('Real_captured', 'Train')
    real_low_test_path, real_normal_test_path = get_v2_paths('Real_captured', 'Test')

    real_train_low = load_images_from_folder(real_low_train_path)
    real_train_normal = load_images_from_folder(real_normal_train_path)
    real_test_low = load_images_from_folder(real_low_test_path)
    real_test_normal = load_images_from_folder(real_normal_test_path)

    print(f"LOL-V2 Real - Train Low: {len(real_train_low)}, Normal: {len(real_train_normal)}")
    print(f"LOL-V2 Real - Test Low: {len(real_test_low)}, Normal: {len(real_test_normal)}")

    # Load LOL-V2 Synthetic training data
    syn_low_train_path, syn_normal_train_path = get_v2_paths('Synthetic', 'Train')
    syn_low_test_path, syn_normal_test_path = get_v2_paths('Synthetic', 'Test')

    syn_train_low = load_images_from_folder(syn_low_train_path)
    syn_train_normal = load_images_from_folder(syn_normal_train_path)
    syn_test_low = load_images_from_folder(syn_low_test_path)
    syn_test_normal = load_images_from_folder(syn_normal_test_path)

    print(f"LOL-V2 Synthetic - Train Low: {len(syn_train_low)}, Normal: {len(syn_train_normal)}")
    print(f"LOL-V2 Synthetic - Test Low: {len(syn_test_low)}, Normal: {len(syn_test_normal)}")
else:
    print("LOL-V2 dataset not found.")

# === Show sample image from LOL-V2 Real if available ===
if len(real_train_low) > 0 and len(real_train_normal) > 0:
    plt.figure(figsize=(20, 10))
    plt.subplot(1, 2, 1)
    plt.title("Real Normal Light", fontsize=20)
    plt.imshow(real_train_normal[0])

    plt.subplot(1, 2, 2)
    plt.title("Real Low Light", fontsize=20)
    plt.imshow(real_train_low[0])
    plt.savefig('lolv2_sample_comparison.png')
    plt.show()
else:
    print("No sample images available to display from LOL-V2 Real_captured.")
# Out:
# 2026-04-05 07:51:21.094336: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1775375481.346279     203 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1775375481.414518     203 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1775375481.990263     203 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775375481.990297     203 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775375481.990299     203 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775375481.990302     203 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Available input paths (first 10):
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/eval15/low/780.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/eval15/low/778.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/eval15/low/493.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/eval15/low/669.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/eval15/low/547.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/eval15/low/55.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/eval15/low/1.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/eval15/low/748.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/eval15/low/22.png
# /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset/eval15/low/146.png
# ... and 4568 more files
# Original LOL dataset found at /kaggle/input/datasets/soumikrakshit/lol-dataset/lol_dataset
# LOL Dataset - Training samples loaded: 485
# LOL Dataset - Validation samples loaded: 15
# LOL-V2 dataset found at /kaggle/input/datasets/tanhyml/lol-v2-dataset/LOL-v2
# LOL-V2 Real - Train Low: 689, Normal: 689
# LOL-V2 Real - Test Low: 100, Normal: 100
# LOL-V2 Synthetic - Train Low: 900, Normal: 900
# LOL-V2 Synthetic - Test Low: 100, Normal: 100

# %%
# Define PSNR metric for evaluation
def psnr_metric(y_true, y_pred):
    return tf.image.psnr(y_true, y_pred, max_val=1.0)

# Data normalization function
def normalize_data(data):
    # Convert to float32 and normalize to [0,1]
    return data.astype('float32') / 255.0
print("done")
# Out:
# done

# %%
# Normalize helper
def normalize_data(images):
    return images.astype(np.float32) / 255.0

# Prepare dataset containers
all_low_images = []
all_high_images = []

# === Original LOL ===
if len(low_images) > 0 and len(high_images) > 0:
    all_low_images.extend(low_images)
    all_high_images.extend(high_images)
    print(f"LOL: {len(low_images)} pairs")

# === LOL-V2 Real_captured ===
if len(real_train_low) > 0 and len(real_train_normal) > 0:
    all_low_images.extend(real_train_low)
    all_high_images.extend(real_train_normal)
    print(f"LOL-V2 Real: {len(real_train_low)} pairs")

# === LOL-V2 Synthetic ===
if len(syn_train_low) > 0 and len(syn_train_normal) > 0:
    all_low_images.extend(syn_train_low)
    all_high_images.extend(syn_train_normal)
    print(f"LOL-V2 Synthetic: {len(syn_train_low)} pairs")

# Check
assert len(all_low_images) == len(all_high_images), "Mismatch in low/high image counts"

# Shuffle and normalize
combined = list(zip(all_low_images, all_high_images))
np.random.shuffle(combined)

all_low_images, all_high_images = zip(*combined)

# Normalize (keeping as lists of arrays with original sizes)
low_norm = [normalize_data(img) for img in all_low_images]
high_norm = [normalize_data(img) for img in all_high_images]

# Validation split (index-based)
val_split = 0.1
val_size = int(len(low_norm) * val_split)

val_indices = np.random.choice(len(low_norm), val_size, replace=False)
train_indices = list(set(range(len(low_norm))) - set(val_indices))

low_train_norm = [low_norm[i] for i in train_indices]
high_train_norm = [high_norm[i] for i in train_indices]
low_val_norm = [low_norm[i] for i in val_indices]
high_val_norm = [high_norm[i] for i in val_indices]

print("\nFinal dataset sizes:")
print("Train pairs:", len(low_train_norm))
print("Validation pairs:", len(low_val_norm))

# Show a few random shapes
print("\nSample input image shapes (mixed):")
for i in range(3):
    print(f"Sample {i+1}: Low shape = {low_train_norm[i].shape}, High shape = {high_train_norm[i].shape}")
# Out:
# LOL: 485 pairs
# LOL-V2 Real: 689 pairs
# LOL-V2 Synthetic: 900 pairs
#
# Final dataset sizes:
# Train pairs: 1867
# Validation pairs: 207
#
# Sample input image shapes (mixed):
# Sample 1: Low shape = (384, 384, 3), High shape = (384, 384, 3)
# Sample 2: Low shape = (384, 384, 3), High shape = (384, 384, 3)
# Sample 3: Low shape = (400, 600, 3), High shape = (400, 600, 3)

# %%
import tensorflow as tf

# ==== Augmentation logic applied on-the-fly ====
def augment_image_pair(low_img, normal_img):
    # Convert to float32 and normalize [0,1]
    low_img = tf.image.convert_image_dtype(low_img, tf.float32)
    normal_img = tf.image.convert_image_dtype(normal_img, tf.float32)

    # Stack for consistent transforms
    combined = tf.stack([low_img, normal_img], axis=0)

    # Random flip
    combined = tf.image.random_flip_left_right(combined)
    combined = tf.image.random_flip_up_down(combined)

    # Random rotation (0 to 3 * 90 degrees)
    k = tf.random.uniform([], minval=0, maxval=4, dtype=tf.int32)
    combined = tf.image.rot90(combined, k)

    # Apply brightness and contrast to only low light input
    low_aug = tf.image.random_brightness(combined[0], max_delta=0.1)
    low_aug = tf.image.random_contrast(low_aug, lower=0.9, upper=1.1)
    normal_aug = combined[1]

    # Resize or pad/crop to standard shape
    low_aug = tf.image.resize_with_crop_or_pad(low_aug, 400, 400)
    normal_aug = tf.image.resize_with_crop_or_pad(normal_aug, 400, 400)

    return low_aug, normal_aug

# Wrapper to use in map()
def tf_augment(low_img, normal_img):
    return augment_image_pair(low_img, normal_img)

# ==== Dataset creation function ====
def make_tf_dataset(low_list, high_list, batch_size=8, shuffle=True, augment=False):
    dataset = tf.data.Dataset.from_tensor_slices((low_list, high_list))

    if shuffle:
        dataset = dataset.shuffle(buffer_size=len(low_list), reshuffle_each_iteration=True)

    if augment:
        dataset = dataset.map(tf_augment, num_parallel_calls=tf.data.AUTOTUNE)

    dataset = dataset.batch(batch_size).prefetch(tf.data.AUTOTUNE)
    return dataset
print("done")
# Out:
# done

# %%
from sklearn.model_selection import train_test_split
import numpy as np

# === Combine all images into lists ===
all_low_images = list(low_images) + list(real_train_low) + list(syn_train_low)
all_high_images = list(high_images) + list(real_train_normal) + list(syn_train_normal)

# === Sanity check ===
assert len(all_low_images) == len(all_high_images), "Mismatch in low/high image counts"

# === Normalize ===
def normalize_data(img_list):
    return [img.astype(np.float32) / 255.0 for img in img_list]

all_low_images = normalize_data(all_low_images)
all_high_images = normalize_data(all_high_images)

# === Train/Val split (index-based, since we’re working with lists of arrays) ===
indices = np.arange(len(all_low_images))
np.random.shuffle(indices)

split = int(len(indices) * 0.9)
train_idx, val_idx = indices[:split], indices[split:]

low_train_norm = [all_low_images[i] for i in train_idx]
high_train_norm = [all_high_images[i] for i in train_idx]
low_val_norm = [all_low_images[i] for i in val_idx]
high_val_norm = [all_high_images[i] for i in val_idx]

print("done")
# Out:
# done

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt
import numpy as np

# === Advanced Data Generator with Improved Augmentations (without TF Addons) ===
class EnhancedImageGenerator(tf.keras.utils.Sequence):
    def __init__(self, X, y, batch_size=4, target_size=(384, 384), augment=False, dataset_weights=None):
        self.X = X
        self.y = y
        self.batch_size = batch_size
        self.target_size = target_size
        self.augment = augment
        # Optional weights to balance between original LOL and LOL-v2
        self.dataset_weights = dataset_weights
        
    def __len__(self):
        return len(self.X) // self.batch_size

    def __getitem__(self, idx):
        X_batch = self.X[idx * self.batch_size : (idx + 1) * self.batch_size]
        y_batch = self.y[idx * self.batch_size : (idx + 1) * self.batch_size]

        X_out, y_out = [], []
        for x, y in zip(X_batch, y_batch):
            x = tf.convert_to_tensor(x, dtype=tf.float32)
            y = tf.convert_to_tensor(y, dtype=tf.float32)

            # Center crop then resize for better quality
            x = tf.image.resize(x, self.target_size, method='bicubic')
            y = tf.image.resize(y, self.target_size, method='bicubic')

            if self.augment:
                # More aggressive augmentation
                if tf.random.uniform(()) > 0.5:
                    x = tf.image.flip_left_right(x)
                    y = tf.image.flip_left_right(y)
                if tf.random.uniform(()) > 0.5:
                    x = tf.image.flip_up_down(x)
                    y = tf.image.flip_up_down(y)
                
                # Color augmentation only for input images
                if tf.random.uniform(()) > 0.5:
                    x = tf.image.random_brightness(x, max_delta=0.2)
                if tf.random.uniform(()) > 0.5:
                    x = tf.image.random_contrast(x, lower=0.8, upper=1.2)
                if tf.random.uniform(()) > 0.7:
                    x = tf.image.random_saturation(x, lower=0.8, upper=1.2)
                if tf.random.uniform(()) > 0.7:
                    x = tf.image.random_hue(x, max_delta=0.05)
                
                # Keep values in valid range
                x = tf.clip_by_value(x, 0.0, 1.0)

            X_out.append(x)
            y_out.append(y)

        return tf.stack(X_out), tf.stack(y_out)

# === Channel Attention Module ===
def channel_attention(input_feature, ratio=8):
    channel = input_feature.shape[-1]
    
    # Shared MLP
    shared_layer_one = layers.Dense(channel//ratio, activation='relu', kernel_initializer='he_normal', use_bias=True)
    shared_layer_two = layers.Dense(channel, kernel_initializer='he_normal', use_bias=True)
    
    # Global average pooling
    avg_pool = layers.GlobalAveragePooling2D()(input_feature)
    avg_pool = layers.Reshape((1, 1, channel))(avg_pool)
    avg_pool = shared_layer_one(avg_pool)
    avg_pool = shared_layer_two(avg_pool)
    
    # Global max pooling
    max_pool = layers.GlobalMaxPooling2D()(input_feature)
    max_pool = layers.Reshape((1, 1, channel))(max_pool)
    max_pool = shared_layer_one(max_pool)
    max_pool = shared_layer_two(max_pool)
    
    # Merge the features and sigmoid activation
    cbam_feature = layers.Add()([avg_pool, max_pool])
    cbam_feature = layers.Activation('sigmoid')(cbam_feature)
    
    # Multiply with input feature
    return layers.Multiply()([input_feature, cbam_feature])

# === Spatial Attention Module ===
def spatial_attention(input_feature):
    # Generate avg and max pooled features across channels
    avg_pool = layers.Lambda(lambda x: tf.reduce_mean(x, axis=3, keepdims=True))(input_feature)
    max_pool = layers.Lambda(lambda x: tf.reduce_max(x, axis=3, keepdims=True))(input_feature)
    
    # Concatenate the features
    concat = layers.Concatenate()([avg_pool, max_pool])
    
    # Apply convolution and activation
    cbam_feature = layers.Conv2D(1, kernel_size=7, padding='same', activation='sigmoid')(concat)
    
    # Multiply with input feature
    return layers.Multiply()([input_feature, cbam_feature])

# === Improved Attention Gate for Spatial Context ===
def attention_gate(x, gating, inter_channels):
    theta_x = layers.Conv2D(inter_channels, kernel_size=1, strides=1, padding='same')(x)
    phi_g = layers.Conv2D(inter_channels, kernel_size=1, strides=1, padding='same')(gating)
    
    # Upsample gating signal if needed to match x dimensions
    if theta_x.shape[1] != phi_g.shape[1] or theta_x.shape[2] != phi_g.shape[2]:
        phi_g = layers.UpSampling2D(size=(theta_x.shape[1] // phi_g.shape[1], 
                                          theta_x.shape[2] // phi_g.shape[2]))(phi_g)
    
    add = layers.Add()([theta_x, phi_g])
    relu = layers.Activation('relu')(add)
    psi = layers.Conv2D(1, kernel_size=1, strides=1, padding='same')(relu)
    sigmoid = layers.Activation('sigmoid')(psi)
    
    # Apply both spatial and channel attention
    attn_out = layers.Multiply()([x, sigmoid])
    return attn_out

# === Residual Block with CBAM (Convolutional Block Attention Module) ===
def residual_block(input_tensor, filters, kernel_size=3):
    x = layers.Conv2D(filters, kernel_size, padding='same')(input_tensor)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    
    x = layers.Conv2D(filters, kernel_size, padding='same')(x)
    x = layers.BatchNormalization()(x)
    
    # Add CBAM attention
    x = channel_attention(x)
    x = spatial_attention(x)
    
    # Skip connection
    if input_tensor.shape[-1] != filters:
        input_tensor = layers.Conv2D(filters, 1, padding='same')(input_tensor)
    
    x = layers.Add()([x, input_tensor])
    x = layers.Activation('relu')(x)
    
    return x

# === Enhanced U-Net with Multi-level Attention and Residual Blocks ===
def build_enhanced_unet(input_shape=(384, 384, 3), num_filters=48):
    inputs = keras.Input(shape=input_shape)
    
    # Initial feature extraction
    x = layers.Conv2D(num_filters, 3, padding='same')(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(num_filters, 3, padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    conv1 = x
    
    # Encoder Path with Residual Blocks
    pool1 = layers.MaxPooling2D(2)(conv1)
    x = residual_block(pool1, num_filters*2)
    conv2 = x
    
    pool2 = layers.MaxPooling2D(2)(conv2)
    x = residual_block(pool2, num_filters*4)
    x = residual_block(x, num_filters*4)
    conv3 = x
    
    pool3 = layers.MaxPooling2D(2)(conv3)
    x = residual_block(pool3, num_filters*8)
    x = residual_block(x, num_filters*8)
    conv4 = x
    
    pool4 = layers.MaxPooling2D(2)(conv4)
    x = residual_block(pool4, num_filters*16)
    x = residual_block(x, num_filters*16)
    bottle = x
    
    # Decoder Path with Enhanced Attention
    up4 = layers.UpSampling2D(2)(bottle)
    attn4 = attention_gate(conv4, up4, num_filters*4)
    concat4 = layers.Concatenate()([up4, attn4])
    x = residual_block(concat4, num_filters*8)
    deconv4 = x
    
    up3 = layers.UpSampling2D(2)(deconv4)
    attn3 = attention_gate(conv3, up3, num_filters*2)
    concat3 = layers.Concatenate()([up3, attn3])
    x = residual_block(concat3, num_filters*4)
    deconv3 = x
    
    up2 = layers.UpSampling2D(2)(deconv3)
    attn2 = attention_gate(conv2, up2, num_filters)
    concat2 = layers.Concatenate()([up2, attn2])
    x = residual_block(concat2, num_filters*2)
    deconv2 = x
    
    up1 = layers.UpSampling2D(2)(deconv2)
    attn1 = attention_gate(conv1, up1, num_filters//2)
    concat1 = layers.Concatenate()([up1, attn1])
    x = residual_block(concat1, num_filters)
    deconv1 = x
    
    # Final output with residual connection from input
    output_conv = layers.Conv2D(3, 1, activation='sigmoid', padding='same')(deconv1)
    
    # Global residual learning (helps with preserving details)
    outputs = layers.Add()([output_conv, inputs])
    outputs = layers.Lambda(lambda x: tf.clip_by_value(x, 0, 1))(outputs)
    
    model = keras.Model(inputs, outputs)
    return model

# === SSIM Loss - Better for perceptual quality ===
def ssim_loss(y_true, y_pred):
    return 1 - tf.reduce_mean(tf.image.ssim(y_true, y_pred, 1.0))

# === Combined Loss Function ===
def combined_loss(y_true, y_pred):
    # MSE for pixel-level accuracy
    mse = tf.reduce_mean(tf.square(y_true - y_pred))
    # SSIM for structural similarity
    ssim = ssim_loss(y_true, y_pred)
    # Combined loss with weighting
    return 0.4 * mse + 0.6 * ssim

# === PSNR Metric ===
def psnr_metric(y_true, y_pred):
    return tf.image.psnr(y_true, y_pred, max_val=1.0)

# === SSIM Metric ===
def ssim_metric(y_true, y_pred):
    return tf.image.ssim(y_true, y_pred, max_val=1.0)

# === Learning Rate Scheduler ===
def lr_scheduler(epoch, lr):
    if epoch < 5:
        return lr
    elif epoch < 15:
        return lr * 0.8
    elif epoch % 8 == 0:
        return lr * 0.8
    else:
        return lr

# === Instantiate the Enhanced Model ===
model = build_enhanced_unet(input_shape=(384, 384, 3), num_filters=48)

# Compile with combined loss
optimizer = keras.optimizers.Adam(learning_rate=0.001)
model.compile(
    optimizer=optimizer,
    loss=combined_loss,
    metrics=[psnr_metric, ssim_metric]
)
model.summary()

# === Create Enhanced Generators ===
# low_train_norm, high_train_norm, low_val_norm, high_val_norm are the normalized data arrays
training_generator = EnhancedImageGenerator(
    low_train_norm, high_train_norm, 
    batch_size=4, 
    augment=True
)

validation_generator = EnhancedImageGenerator(
    low_val_norm, high_val_norm, 
    batch_size=4, 
    augment=False
)

# === Callbacks ===
callbacks = [
    tf.keras.callbacks.LearningRateScheduler(lr_scheduler),
    tf.keras.callbacks.ModelCheckpoint(
        'best_low_light_model.keras',
        monitor='val_psnr_metric',
        mode='max',
        save_best_only=True,
        verbose=1
    ),
    tf.keras.callbacks.EarlyStopping(
        monitor='val_psnr_metric',
        mode='max',
        patience=12,
        restore_best_weights=True,
        verbose=1
    )
]

# === Train the Model ===
history = model.fit(
    training_generator,
    validation_data=validation_generator,
    epochs=80,  # More epochs with early stopping
    callbacks=callbacks,
    verbose=1
)

# === Plot Training History ===
plt.figure(figsize=(18, 6))

plt.subplot(1, 3, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Combined Loss')
plt.legend()

plt.subplot(1, 3, 2)
plt.plot(history.history['psnr_metric'], label='Training PSNR')
plt.plot(history.history['val_psnr_metric'], label='Validation PSNR')
plt.title('PSNR over Epochs')
plt.xlabel('Epoch')
plt.ylabel('PSNR (dB)')
plt.legend()

plt.subplot(1, 3, 3)
plt.plot(history.history['ssim_metric'], label='Training SSIM')
plt.plot(history.history['val_ssim_metric'], label='Validation SSIM')
plt.title('SSIM over Epochs')
plt.xlabel('Epoch')
plt.ylabel('SSIM')
plt.legend()

plt.tight_layout()
plt.savefig('enhanced_training_history.png')
plt.show()

# === Visualize Some Results ===
def visualize_results(model, low_images, high_images, num_samples=3):
    plt.figure(figsize=(15, 5*num_samples))
    
    # Randomly select samples
    indices = np.random.randint(0, len(low_images), num_samples)
    
    for i, idx in enumerate(indices):
        # Get images
        low_img = low_images[idx]
        high_img = high_images[idx]
        
        # Ensure 4D tensor for prediction
        low_tensor = tf.expand_dims(low_img, 0)
        
        # Predict enhanced image
        pred_img = model.predict(low_tensor)[0]
        
        # Display images
        plt.subplot(num_samples, 3, i*3 + 1)
        plt.imshow(low_img)
        plt.title(f'Low Light Input')
        plt.axis('off')
        
        plt.subplot(num_samples, 3, i*3 + 2)
        plt.imshow(pred_img)
        plt.title(f'Model Output (PSNR: {psnr_metric(high_img[np.newaxis,...], pred_img[np.newaxis,...]).numpy():.2f}dB)')
        plt.axis('off')
        
        plt.subplot(num_samples, 3, i*3 + 3)
        plt.imshow(high_img)
        plt.title('Ground Truth')
        plt.axis('off')
    
    plt.tight_layout()
    plt.savefig('result_comparison.png')
    plt.show()
# Out:
# I0000 00:00:1775375611.604630     203 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15511 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 384, 384,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 384, 384,  │      1,344 │ input_layer[0][0] │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 384, 384,  │        192 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 384, 384,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 384, 384,  │     20,784 │ activation[0][0]  │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 384, 384,  │        192 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 384, 384,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 192, 192,  │          0 │ activation_1[0][… │
# │ (MaxPooling2D)      │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 192, 192,  │     41,568 │ max_pooling2d[0]… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 192, 192,  │        384 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 192, 192,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 192, 192,  │     83,040 │ activation_2[0][… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 192, 192,  │        384 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 96)        │          0 │ batch_normalizat… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_max_pooling… │ (None, 96)        │          0 │ batch_normalizat… │
# │ (GlobalMaxPooling2… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape (Reshape)   │ (None, 1, 1, 96)  │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_1 (Reshape) │ (None, 1, 1, 96)  │          0 │ global_max_pooli… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 1, 1, 12)  │      1,164 │ reshape[0][0],    │
# │                     │                   │            │ reshape_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 1, 1, 96)  │      1,248 │ dense[0][0],      │
# │                     │                   │            │ dense[1][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 1, 1, 96)  │          0 │ dense_1[0][0],    │
# │                     │                   │            │ dense_1[1][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 1, 1, 96)  │          0 │ add[0][0]         │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply (Multiply) │ (None, 192, 192,  │          0 │ batch_normalizat… │
# │                     │ 96)               │            │ activation_3[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda (Lambda)     │ (None, 192, 192,  │          0 │ multiply[0][0]    │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_1 (Lambda)   │ (None, 192, 192,  │          0 │ multiply[0][0]    │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 192, 192,  │          0 │ lambda[0][0],     │
# │ (Concatenate)       │ 2)                │            │ lambda_1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 192, 192,  │         99 │ concatenate[0][0] │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_1          │ (None, 192, 192,  │          0 │ multiply[0][0],   │
# │ (Multiply)          │ 96)               │            │ conv2d_4[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 192, 192,  │      4,704 │ max_pooling2d[0]… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 192, 192,  │          0 │ multiply_1[0][0], │
# │                     │ 96)               │            │ conv2d_5[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 192, 192,  │          0 │ add_1[0][0]       │
# │ (Activation)        │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 96, 96,    │          0 │ activation_4[0][… │
# │ (MaxPooling2D)      │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 96, 96,    │    166,080 │ max_pooling2d_1[… │
# │                     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 96, 96,    │        768 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 96, 96,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 96, 96,    │    331,968 │ activation_5[0][… │
# │                     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 96, 96,    │        768 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 192)       │          0 │ batch_normalizat… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_max_pooling… │ (None, 192)       │          0 │ batch_normalizat… │
# │ (GlobalMaxPooling2… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_2 (Reshape) │ (None, 1, 1, 192) │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_3 (Reshape) │ (None, 1, 1, 192) │          0 │ global_max_pooli… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 1, 1, 24)  │      4,632 │ reshape_2[0][0],  │
# │                     │                   │            │ reshape_3[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 1, 1, 192) │      4,800 │ dense_2[0][0],    │
# │                     │                   │            │ dense_2[1][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 1, 1, 192) │          0 │ dense_3[0][0],    │
# │                     │                   │            │ dense_3[1][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 1, 1, 192) │          0 │ add_2[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_2          │ (None, 96, 96,    │          0 │ batch_normalizat… │
# │ (Multiply)          │ 192)              │            │ activation_6[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_2 (Lambda)   │ (None, 96, 96, 1) │          0 │ multiply_2[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_3 (Lambda)   │ (None, 96, 96, 1) │          0 │ multiply_2[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 96, 96, 2) │          0 │ lambda_2[0][0],   │
# │ (Concatenate)       │                   │            │ lambda_3[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 96, 96, 1) │         99 │ concatenate_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_3          │ (None, 96, 96,    │          0 │ multiply_2[0][0], │
# │ (Multiply)          │ 192)              │            │ conv2d_8[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 96, 96,    │     18,624 │ max_pooling2d_1[… │
# │                     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 96, 96,    │          0 │ multiply_3[0][0], │
# │                     │ 192)              │            │ conv2d_9[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 96, 96,    │          0 │ add_3[0][0]       │
# │ (Activation)        │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 96, 96,    │    331,968 │ activation_7[0][… │
# │                     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 96, 96,    │        768 │ conv2d_10[0][0]   │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (None, 96, 96,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 96, 96,    │    331,968 │ activation_8[0][… │
# │                     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 96, 96,    │        768 │ conv2d_11[0][0]   │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 192)       │          0 │ batch_normalizat… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_max_pooling… │ (None, 192)       │          0 │ batch_normalizat… │
# │ (GlobalMaxPooling2… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_4 (Reshape) │ (None, 1, 1, 192) │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_5 (Reshape) │ (None, 1, 1, 192) │          0 │ global_max_pooli… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 1, 1, 24)  │      4,632 │ reshape_4[0][0],  │
# │                     │                   │            │ reshape_5[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 1, 1, 192) │      4,800 │ dense_4[0][0],    │
# │                     │                   │            │ dense_4[1][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 1, 1, 192) │          0 │ dense_5[0][0],    │
# │                     │                   │            │ dense_5[1][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_9        │ (None, 1, 1, 192) │          0 │ add_4[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_4          │ (None, 96, 96,    │          0 │ batch_normalizat… │
# │ (Multiply)          │ 192)              │            │ activation_9[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_4 (Lambda)   │ (None, 96, 96, 1) │          0 │ multiply_4[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_5 (Lambda)   │ (None, 96, 96, 1) │          0 │ multiply_4[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 96, 96, 2) │          0 │ lambda_4[0][0],   │
# │ (Concatenate)       │                   │            │ lambda_5[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 96, 96, 1) │         99 │ concatenate_2[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_5          │ (None, 96, 96,    │          0 │ multiply_4[0][0], │
# │ (Multiply)          │ 192)              │            │ conv2d_12[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_5 (Add)         │ (None, 96, 96,    │          0 │ multiply_5[0][0], │
# │                     │ 192)              │            │ activation_7[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_10       │ (None, 96, 96,    │          0 │ add_5[0][0]       │
# │ (Activation)        │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 48, 48,    │          0 │ activation_10[0]… │
# │ (MaxPooling2D)      │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 48, 48,    │    663,936 │ max_pooling2d_2[… │
# │                     │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 48, 48,    │      1,536 │ conv2d_13[0][0]   │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_11       │ (None, 48, 48,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 48, 48,    │  1,327,488 │ activation_11[0]… │
# │                     │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 48, 48,    │      1,536 │ conv2d_14[0][0]   │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 384)       │          0 │ batch_normalizat… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_max_pooling… │ (None, 384)       │          0 │ batch_normalizat… │
# │ (GlobalMaxPooling2… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_6 (Reshape) │ (None, 1, 1, 384) │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_7 (Reshape) │ (None, 1, 1, 384) │          0 │ global_max_pooli… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 1, 1, 48)  │     18,480 │ reshape_6[0][0],  │
# │                     │                   │            │ reshape_7[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 1, 1, 384) │     18,816 │ dense_6[0][0],    │
# │                     │                   │            │ dense_6[1][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_6 (Add)         │ (None, 1, 1, 384) │          0 │ dense_7[0][0],    │
# │                     │                   │            │ dense_7[1][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_12       │ (None, 1, 1, 384) │          0 │ add_6[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_6          │ (None, 48, 48,    │          0 │ batch_normalizat… │
# │ (Multiply)          │ 384)              │            │ activation_12[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_6 (Lambda)   │ (None, 48, 48, 1) │          0 │ multiply_6[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_7 (Lambda)   │ (None, 48, 48, 1) │          0 │ multiply_6[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 48, 48, 2) │          0 │ lambda_6[0][0],   │
# │ (Concatenate)       │                   │            │ lambda_7[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 48, 48, 1) │         99 │ concatenate_3[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_7          │ (None, 48, 48,    │          0 │ multiply_6[0][0], │
# │ (Multiply)          │ 384)              │            │ conv2d_15[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 48, 48,    │     74,112 │ max_pooling2d_2[… │
# │                     │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_7 (Add)         │ (None, 48, 48,    │          0 │ multiply_7[0][0], │
# │                     │ 384)              │            │ conv2d_16[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_13       │ (None, 48, 48,    │          0 │ add_7[0][0]       │
# │ (Activation)        │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 48, 48,    │  1,327,488 │ activation_13[0]… │
# │                     │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 48, 48,    │      1,536 │ conv2d_17[0][0]   │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_14       │ (None, 48, 48,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 48, 48,    │  1,327,488 │ activation_14[0]… │
# │                     │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 48, 48,    │      1,536 │ conv2d_18[0][0]   │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 384)       │          0 │ batch_normalizat… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_max_pooling… │ (None, 384)       │          0 │ batch_normalizat… │
# │ (GlobalMaxPooling2… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_8 (Reshape) │ (None, 1, 1, 384) │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_9 (Reshape) │ (None, 1, 1, 384) │          0 │ global_max_pooli… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_8 (Dense)     │ (None, 1, 1, 48)  │     18,480 │ reshape_8[0][0],  │
# │                     │                   │            │ reshape_9[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_9 (Dense)     │ (None, 1, 1, 384) │     18,816 │ dense_8[0][0],    │
# │                     │                   │            │ dense_8[1][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_8 (Add)         │ (None, 1, 1, 384) │          0 │ dense_9[0][0],    │
# │                     │                   │            │ dense_9[1][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_15       │ (None, 1, 1, 384) │          0 │ add_8[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_8          │ (None, 48, 48,    │          0 │ batch_normalizat… │
# │ (Multiply)          │ 384)              │            │ activation_15[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_8 (Lambda)   │ (None, 48, 48, 1) │          0 │ multiply_8[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_9 (Lambda)   │ (None, 48, 48, 1) │          0 │ multiply_8[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_4       │ (None, 48, 48, 2) │          0 │ lambda_8[0][0],   │
# │ (Concatenate)       │                   │            │ lambda_9[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_19 (Conv2D)  │ (None, 48, 48, 1) │         99 │ concatenate_4[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_9          │ (None, 48, 48,    │          0 │ multiply_8[0][0], │
# │ (Multiply)          │ 384)              │            │ conv2d_19[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_9 (Add)         │ (None, 48, 48,    │          0 │ multiply_9[0][0], │
# │                     │ 384)              │            │ activation_13[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_16       │ (None, 48, 48,    │          0 │ add_9[0][0]       │
# │ (Activation)        │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 24, 24,    │          0 │ activation_16[0]… │
# │ (MaxPooling2D)      │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_20 (Conv2D)  │ (None, 24, 24,    │  2,654,976 │ max_pooling2d_3[… │
# │                     │ 768)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 24, 24,    │      3,072 │ conv2d_20[0][0]   │
# │ (BatchNormalizatio… │ 768)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_17       │ (None, 24, 24,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 768)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_21 (Conv2D)  │ (None, 24, 24,    │  5,309,184 │ activation_17[0]… │
# │                     │ 768)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 24, 24,    │      3,072 │ conv2d_21[0][0]   │
# │ (BatchNormalizatio… │ 768)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 768)       │          0 │ batch_normalizat… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_max_pooling… │ (None, 768)       │          0 │ batch_normalizat… │
# │ (GlobalMaxPooling2… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_10          │ (None, 1, 1, 768) │          0 │ global_average_p… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_11          │ (None, 1, 1, 768) │          0 │ global_max_pooli… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_10 (Dense)    │ (None, 1, 1, 96)  │     73,824 │ reshape_10[0][0], │
# │                     │                   │            │ reshape_11[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_11 (Dense)    │ (None, 1, 1, 768) │     74,496 │ dense_10[0][0],   │
# │                     │                   │            │ dense_10[1][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_10 (Add)        │ (None, 1, 1, 768) │          0 │ dense_11[0][0],   │
# │                     │                   │            │ dense_11[1][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_18       │ (None, 1, 1, 768) │          0 │ add_10[0][0]      │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_10         │ (None, 24, 24,    │          0 │ batch_normalizat… │
# │ (Multiply)          │ 768)              │            │ activation_18[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_10 (Lambda)  │ (None, 24, 24, 1) │          0 │ multiply_10[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_11 (Lambda)  │ (None, 24, 24, 1) │          0 │ multiply_10[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_5       │ (None, 24, 24, 2) │          0 │ lambda_10[0][0],  │
# │ (Concatenate)       │                   │            │ lambda_11[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_22 (Conv2D)  │ (None, 24, 24, 1) │         99 │ concatenate_5[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_11         │ (None, 24, 24,    │          0 │ multiply_10[0][0… │
# │ (Multiply)          │ 768)              │            │ conv2d_22[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_23 (Conv2D)  │ (None, 24, 24,    │    295,680 │ max_pooling2d_3[… │
# │                     │ 768)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_11 (Add)        │ (None, 24, 24,    │          0 │ multiply_11[0][0… │
# │                     │ 768)              │            │ conv2d_23[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_19       │ (None, 24, 24,    │          0 │ add_11[0][0]      │
# │ (Activation)        │ 768)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_24 (Conv2D)  │ (None, 24, 24,    │  5,309,184 │ activation_19[0]… │
# │                     │ 768)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 24, 24,    │      3,072 │ conv2d_24[0][0]   │
# │ (BatchNormalizatio… │ 768)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_20       │ (None, 24, 24,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 768)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_25 (Conv2D)  │ (None, 24, 24,    │  5,309,184 │ activation_20[0]… │
# │                     │ 768)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 24, 24,    │      3,072 │ conv2d_25[0][0]   │
# │ (BatchNormalizatio… │ 768)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 768)       │          0 │ batch_normalizat… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_max_pooling… │ (None, 768)       │          0 │ batch_normalizat… │
# │ (GlobalMaxPooling2… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_12          │ (None, 1, 1, 768) │          0 │ global_average_p… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_13          │ (None, 1, 1, 768) │          0 │ global_max_pooli… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_12 (Dense)    │ (None, 1, 1, 96)  │     73,824 │ reshape_12[0][0], │
# │                     │                   │            │ reshape_13[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_13 (Dense)    │ (None, 1, 1, 768) │     74,496 │ dense_12[0][0],   │
# │                     │                   │            │ dense_12[1][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_12 (Add)        │ (None, 1, 1, 768) │          0 │ dense_13[0][0],   │
# │                     │                   │            │ dense_13[1][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_21       │ (None, 1, 1, 768) │          0 │ add_12[0][0]      │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_12         │ (None, 24, 24,    │          0 │ batch_normalizat… │
# │ (Multiply)          │ 768)              │            │ activation_21[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_12 (Lambda)  │ (None, 24, 24, 1) │          0 │ multiply_12[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_13 (Lambda)  │ (None, 24, 24, 1) │          0 │ multiply_12[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_6       │ (None, 24, 24, 2) │          0 │ lambda_12[0][0],  │
# │ (Concatenate)       │                   │            │ lambda_13[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_26 (Conv2D)  │ (None, 24, 24, 1) │         99 │ concatenate_6[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_13         │ (None, 24, 24,    │          0 │ multiply_12[0][0… │
# │ (Multiply)          │ 768)              │            │ conv2d_26[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_13 (Add)        │ (None, 24, 24,    │          0 │ multiply_13[0][0… │
# │                     │ 768)              │            │ activation_19[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_22       │ (None, 24, 24,    │          0 │ add_13[0][0]      │
# │ (Activation)        │ 768)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d       │ (None, 48, 48,    │          0 │ activation_22[0]… │
# │ (UpSampling2D)      │ 768)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_27 (Conv2D)  │ (None, 48, 48,    │     73,920 │ activation_16[0]… │
# │                     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_28 (Conv2D)  │ (None, 48, 48,    │    147,648 │ up_sampling2d[0]… │
# │                     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_14 (Add)        │ (None, 48, 48,    │          0 │ conv2d_27[0][0],  │
# │                     │ 192)              │            │ conv2d_28[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_23       │ (None, 48, 48,    │          0 │ add_14[0][0]      │
# │ (Activation)        │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_29 (Conv2D)  │ (None, 48, 48, 1) │        193 │ activation_23[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_24       │ (None, 48, 48, 1) │          0 │ conv2d_29[0][0]   │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_14         │ (None, 48, 48,    │          0 │ activation_16[0]… │
# │ (Multiply)          │ 384)              │            │ activation_24[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_7       │ (None, 48, 48,    │          0 │ up_sampling2d[0]… │
# │ (Concatenate)       │ 1152)             │            │ multiply_14[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_30 (Conv2D)  │ (None, 48, 48,    │  3,981,696 │ concatenate_7[0]… │
# │                     │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 48, 48,    │      1,536 │ conv2d_30[0][0]   │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_25       │ (None, 48, 48,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_31 (Conv2D)  │ (None, 48, 48,    │  1,327,488 │ activation_25[0]… │
# │                     │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 48, 48,    │      1,536 │ conv2d_31[0][0]   │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 384)       │          0 │ batch_normalizat… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_max_pooling… │ (None, 384)       │          0 │ batch_normalizat… │
# │ (GlobalMaxPooling2… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_14          │ (None, 1, 1, 384) │          0 │ global_average_p… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_15          │ (None, 1, 1, 384) │          0 │ global_max_pooli… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_14 (Dense)    │ (None, 1, 1, 48)  │     18,480 │ reshape_14[0][0], │
# │                     │                   │            │ reshape_15[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_15 (Dense)    │ (None, 1, 1, 384) │     18,816 │ dense_14[0][0],   │
# │                     │                   │            │ dense_14[1][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_15 (Add)        │ (None, 1, 1, 384) │          0 │ dense_15[0][0],   │
# │                     │                   │            │ dense_15[1][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_26       │ (None, 1, 1, 384) │          0 │ add_15[0][0]      │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_15         │ (None, 48, 48,    │          0 │ batch_normalizat… │
# │ (Multiply)          │ 384)              │            │ activation_26[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_14 (Lambda)  │ (None, 48, 48, 1) │          0 │ multiply_15[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_15 (Lambda)  │ (None, 48, 48, 1) │          0 │ multiply_15[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_8       │ (None, 48, 48, 2) │          0 │ lambda_14[0][0],  │
# │ (Concatenate)       │                   │            │ lambda_15[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_32 (Conv2D)  │ (None, 48, 48, 1) │         99 │ concatenate_8[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_16         │ (None, 48, 48,    │          0 │ multiply_15[0][0… │
# │ (Multiply)          │ 384)              │            │ conv2d_32[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_33 (Conv2D)  │ (None, 48, 48,    │    442,752 │ concatenate_7[0]… │
# │                     │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_16 (Add)        │ (None, 48, 48,    │          0 │ multiply_16[0][0… │
# │                     │ 384)              │            │ conv2d_33[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_27       │ (None, 48, 48,    │          0 │ add_16[0][0]      │
# │ (Activation)        │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_1     │ (None, 96, 96,    │          0 │ activation_27[0]… │
# │ (UpSampling2D)      │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_34 (Conv2D)  │ (None, 96, 96,    │     18,528 │ activation_10[0]… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_35 (Conv2D)  │ (None, 96, 96,    │     36,960 │ up_sampling2d_1[… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_17 (Add)        │ (None, 96, 96,    │          0 │ conv2d_34[0][0],  │
# │                     │ 96)               │            │ conv2d_35[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_28       │ (None, 96, 96,    │          0 │ add_17[0][0]      │
# │ (Activation)        │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_36 (Conv2D)  │ (None, 96, 96, 1) │         97 │ activation_28[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_29       │ (None, 96, 96, 1) │          0 │ conv2d_36[0][0]   │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_17         │ (None, 96, 96,    │          0 │ activation_10[0]… │
# │ (Multiply)          │ 192)              │            │ activation_29[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_9       │ (None, 96, 96,    │          0 │ up_sampling2d_1[… │
# │ (Concatenate)       │ 576)              │            │ multiply_17[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_37 (Conv2D)  │ (None, 96, 96,    │    995,520 │ concatenate_9[0]… │
# │                     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 96, 96,    │        768 │ conv2d_37[0][0]   │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_30       │ (None, 96, 96,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_38 (Conv2D)  │ (None, 96, 96,    │    331,968 │ activation_30[0]… │
# │                     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 96, 96,    │        768 │ conv2d_38[0][0]   │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 192)       │          0 │ batch_normalizat… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_max_pooling… │ (None, 192)       │          0 │ batch_normalizat… │
# │ (GlobalMaxPooling2… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_16          │ (None, 1, 1, 192) │          0 │ global_average_p… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_17          │ (None, 1, 1, 192) │          0 │ global_max_pooli… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_16 (Dense)    │ (None, 1, 1, 24)  │      4,632 │ reshape_16[0][0], │
# │                     │                   │            │ reshape_17[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_17 (Dense)    │ (None, 1, 1, 192) │      4,800 │ dense_16[0][0],   │
# │                     │                   │            │ dense_16[1][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_18 (Add)        │ (None, 1, 1, 192) │          0 │ dense_17[0][0],   │
# │                     │                   │            │ dense_17[1][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_31       │ (None, 1, 1, 192) │          0 │ add_18[0][0]      │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_18         │ (None, 96, 96,    │          0 │ batch_normalizat… │
# │ (Multiply)          │ 192)              │            │ activation_31[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_16 (Lambda)  │ (None, 96, 96, 1) │          0 │ multiply_18[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# ...
# Epoch 21/80
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step - loss: 0.1086 - psnr_metric: 21.2125 - ssim_metric: 0.8289
# Epoch 21: val_psnr_metric did not improve from 23.98214
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 176s 378ms/step - loss: 0.1086 - psnr_metric: 21.2131 - ssim_metric: 0.8289 - val_loss: 0.0788 - val_psnr_metric: 23.6649 - val_ssim_metric: 0.8760 - learning_rate: 8.5899e-05
# Epoch 22/80
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - loss: 0.1054 - psnr_metric: 21.3947 - ssim_metric: 0.8340
# Epoch 22: val_psnr_metric did not improve from 23.98214
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 176s 378ms/step - loss: 0.1054 - psnr_metric: 21.3944 - ssim_metric: 0.8340 - val_loss: 0.0776 - val_psnr_metric: 23.8852 - val_ssim_metric: 0.8778 - learning_rate: 8.5899e-05
# Epoch 23/80
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - loss: 0.1029 - psnr_metric: 21.4096 - ssim_metric: 0.8381
# Epoch 23: val_psnr_metric did not improve from 23.98214
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 176s 379ms/step - loss: 0.1029 - psnr_metric: 21.4098 - ssim_metric: 0.8381 - val_loss: 0.0769 - val_psnr_metric: 23.4116 - val_ssim_metric: 0.8790 - learning_rate: 8.5899e-05
# Epoch 24/80
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - loss: 0.1041 - psnr_metric: 21.5727 - ssim_metric: 0.8359
# Epoch 24: val_psnr_metric did not improve from 23.98214
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 177s 379ms/step - loss: 0.1041 - psnr_metric: 21.5726 - ssim_metric: 0.8359 - val_loss: 0.0759 - val_psnr_metric: 23.2031 - val_ssim_metric: 0.8804 - learning_rate: 8.5899e-05
# Epoch 25/80
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step - loss: 0.1042 - psnr_metric: 21.4961 - ssim_metric: 0.8360
# Epoch 25: val_psnr_metric did not improve from 23.98214
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 176s 377ms/step - loss: 0.1042 - psnr_metric: 21.4959 - ssim_metric: 0.8360 - val_loss: 0.0751 - val_psnr_metric: 23.9379 - val_ssim_metric: 0.8814 - learning_rate: 6.8719e-05
# Epoch 26/80
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - loss: 0.1052 - psnr_metric: 21.7387 - ssim_metric: 0.8341
# Epoch 26: val_psnr_metric did not improve from 23.98214
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 176s 378ms/step - loss: 0.1052 - psnr_metric: 21.7386 - ssim_metric: 0.8341 - val_loss: 0.0764 - val_psnr_metric: 23.8033 - val_ssim_metric: 0.8795 - learning_rate: 6.8719e-05
# Epoch 27/80
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step - loss: 0.1086 - psnr_metric: 21.0948 - ssim_metric: 0.8288
# Epoch 27: val_psnr_metric did not improve from 23.98214
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 176s 378ms/step - loss: 0.1086 - psnr_metric: 21.0955 - ssim_metric: 0.8288 - val_loss: 0.0761 - val_psnr_metric: 23.8373 - val_ssim_metric: 0.8800 - learning_rate: 6.8719e-05
# Epoch 28/80
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step - loss: 0.1020 - psnr_metric: 21.7556 - ssim_metric: 0.8388
# Epoch 28: val_psnr_metric improved from 23.98214 to 24.28572, saving model to best_low_light_model.keras
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 180s 386ms/step - loss: 0.1020 - psnr_metric: 21.7562 - ssim_metric: 0.8388 - val_loss: 0.0757 - val_psnr_metric: 24.2857 - val_ssim_metric: 0.8807 - learning_rate: 6.8719e-05
# Epoch 29/80
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - loss: 0.1005 - psnr_metric: 21.6994 - ssim_metric: 0.8416
# Epoch 29: val_psnr_metric improved from 24.28572 to 24.30721, saving model to best_low_light_model.keras
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 182s 390ms/step - loss: 0.1005 - psnr_metric: 21.6997 - ssim_metric: 0.8416 - val_loss: 0.0748 - val_psnr_metric: 24.3072 - val_ssim_metric: 0.8821 - learning_rate: 6.8719e-05
# Epoch 30/80
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step - loss: 0.0993 - psnr_metric: 22.0724 - ssim_metric: 0.8432
# Epoch 30: val_psnr_metric did not improve from 24.30721
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 179s 385ms/step - loss: 0.0993 - psnr_metric: 22.0720 - ssim_metric: 0.8432 - val_loss: 0.0746 - val_psnr_metric: 24.1162 - val_ssim_metric: 0.8823 - learning_rate: 6.8719e-05
# Epoch 31/80
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - loss: 0.1035 - psnr_metric: 21.9380 - ssim_metric: 0.8369
# Epoch 31: val_psnr_metric did not improve from 24.30721
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 180s 386ms/step - loss: 0.1035 - psnr_metric: 21.9377 - ssim_metric: 0.8369 - val_loss: 0.0751 - val_psnr_metric: 23.7218 - val_ssim_metric: 0.8815 - learning_rate: 6.8719e-05
# Epoch 32/80
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - loss: 0.1046 - psnr_metric: 21.5505 - ssim_metric: 0.8353
# Epoch 32: val_psnr_metric did not improve from 24.30721
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 180s 386ms/step - loss: 0.1046 - psnr_metric: 21.5510 - ssim_metric: 0.8353 - val_loss: 0.0755 - val_psnr_metric: 23.8010 - val_ssim_metric: 0.8810 - learning_rate: 6.8719e-05
# Epoch 33/80
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - loss: 0.1002 - psnr_metric: 22.0101 - ssim_metric: 0.8415
# Epoch 33: val_psnr_metric did not improve from 24.30721
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 180s 386ms/step - loss: 0.1002 - psnr_metric: 22.0098 - ssim_metric: 0.8415 - val_loss: 0.0738 - val_psnr_metric: 24.2714 - val_ssim_metric: 0.8836 - learning_rate: 5.4976e-05
# Epoch 34/80
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - loss: 0.1015 - psnr_metric: 21.8070 - ssim_metric: 0.8398
# Epoch 34: val_psnr_metric did not improve from 24.30721
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 180s 386ms/step - loss: 0.1015 - psnr_metric: 21.8071 - ssim_metric: 0.8398 - val_loss: 0.0761 - val_psnr_metric: 24.0778 - val_ssim_metric: 0.8800 - learning_rate: 5.4976e-05
# Epoch 35/80
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step - loss: 0.0989 - psnr_metric: 21.7781 - ssim_metric: 0.8440
# Epoch 35: val_psnr_metric did not improve from 24.30721
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 179s 384ms/step - loss: 0.0989 - psnr_metric: 21.7782 - ssim_metric: 0.8440 - val_loss: 0.0740 - val_psnr_metric: 24.1979 - val_ssim_metric: 0.8834 - learning_rate: 5.4976e-05
# Epoch 36/80
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step - loss: 0.1056 - psnr_metric: 21.5693 - ssim_metric: 0.8332
# Epoch 36: val_psnr_metric did not improve from 24.30721
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 178s 383ms/step - loss: 0.1056 - psnr_metric: 21.5695 - ssim_metric: 0.8332 - val_loss: 0.0730 - val_psnr_metric: 24.0695 - val_ssim_metric: 0.8849 - learning_rate: 5.4976e-05
# Epoch 37/80
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step - loss: 0.1025 - psnr_metric: 22.0258 - ssim_metric: 0.8381
# Epoch 37: val_psnr_metric improved from 24.30721 to 24.44638, saving model to best_low_light_model.keras
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 182s 390ms/step - loss: 0.1025 - psnr_metric: 22.0260 - ssim_metric: 0.8381 - val_loss: 0.0736 - val_psnr_metric: 24.4464 - val_ssim_metric: 0.8839 - learning_rate: 5.4976e-05
# Epoch 38/80
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step - loss: 0.0980 - psnr_metric: 22.0526 - ssim_metric: 0.8455
# Epoch 38: val_psnr_metric improved from 24.44638 to 24.44755, saving model to best_low_light_model.keras
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 182s 390ms/step - loss: 0.0980 - psnr_metric: 22.0526 - ssim_metric: 0.8455 - val_loss: 0.0736 - val_psnr_metric: 24.4475 - val_ssim_metric: 0.8840 - learning_rate: 5.4976e-05
# Epoch 39/80
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - loss: 0.0955 - psnr_metric: 22.5544 - ssim_metric: 0.8490
# Epoch 39: val_psnr_metric improved from 24.44755 to 24.76512, saving model to best_low_light_model.keras
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 183s 392ms/step - loss: 0.0955 - psnr_metric: 22.5535 - ssim_metric: 0.8490 - val_loss: 0.0743 - val_psnr_metric: 24.7651 - val_ssim_metric: 0.8829 - learning_rate: 5.4976e-05
# Epoch 40/80
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - loss: 0.0962 - psnr_metric: 22.3049 - ssim_metric: 0.8482
# Epoch 40: val_psnr_metric did not improve from 24.76512
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 180s 385ms/step - loss: 0.0962 - psnr_metric: 22.3043 - ssim_metric: 0.8482 - val_loss: 0.0742 - val_psnr_metric: 24.4777 - val_ssim_metric: 0.8832 - learning_rate: 5.4976e-05
# Epoch 41/80
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step - loss: 0.1024 - psnr_metric: 22.1369 - ssim_metric: 0.8383
# Epoch 41: val_psnr_metric did not improve from 24.76512
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 180s 386ms/step - loss: 0.1024 - psnr_metric: 22.1371 - ssim_metric: 0.8383 - val_loss: 0.0734 - val_psnr_metric: 24.6144 - val_ssim_metric: 0.8842 - learning_rate: 4.3980e-05
# Epoch 42/80
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - loss: 0.0996 - psnr_metric: 21.7544 - ssim_metric: 0.8429
# Epoch 42: val_psnr_metric did not improve from 24.76512
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 180s 386ms/step - loss: 0.0996 - psnr_metric: 21.7552 - ssim_metric: 0.8429 - val_loss: 0.0745 - val_psnr_metric: 24.6642 - val_ssim_metric: 0.8826 - learning_rate: 4.3980e-05
# Epoch 43/80
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step - loss: 0.1019 - psnr_metric: 22.0675 - ssim_metric: 0.8389
# Epoch 43: val_psnr_metric did not improve from 24.76512
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 181s 388ms/step - loss: 0.1019 - psnr_metric: 22.0679 - ssim_metric: 0.8389 - val_loss: 0.0745 - val_psnr_metric: 24.4155 - val_ssim_metric: 0.8827 - learning_rate: 4.3980e-05
# Epoch 44/80
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - loss: 0.0967 - psnr_metric: 22.2433 - ssim_metric: 0.8471
# Epoch 44: val_psnr_metric did not improve from 24.76512
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 179s 384ms/step - loss: 0.0967 - psnr_metric: 22.2429 - ssim_metric: 0.8471 - val_loss: 0.0727 - val_psnr_metric: 24.6968 - val_ssim_metric: 0.8853 - learning_rate: 4.3980e-05
# Epoch 45/80
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step - loss: 0.0951 - psnr_metric: 22.1935 - ssim_metric: 0.8496
# Epoch 45: val_psnr_metric improved from 24.76512 to 25.10139, saving model to best_low_light_model.keras
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 181s 389ms/step - loss: 0.0951 - psnr_metric: 22.1937 - ssim_metric: 0.8496 - val_loss: 0.0722 - val_psnr_metric: 25.1014 - val_ssim_metric: 0.8862 - learning_rate: 4.3980e-05
# Epoch 46/80
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step - loss: 0.0964 - psnr_metric: 22.3109 - ssim_metric: 0.8476
# Epoch 46: val_psnr_metric improved from 25.10139 to 25.19601, saving model to best_low_light_model.keras
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 182s 390ms/step - loss: 0.0964 - psnr_metric: 22.3107 - ssim_metric: 0.8476 - val_loss: 0.0736 - val_psnr_metric: 25.1960 - val_ssim_metric: 0.8839 - learning_rate: 4.3980e-05
# Epoch 47/80
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - loss: 0.0979 - psnr_metric: 22.4684 - ssim_metric: 0.8450
# Epoch 47: val_psnr_metric did not improve from 25.19601
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 180s 386ms/step - loss: 0.0979 - psnr_metric: 22.4680 - ssim_metric: 0.8450 - val_loss: 0.0723 - val_psnr_metric: 24.5254 - val_ssim_metric: 0.8860 - learning_rate: 4.3980e-05
# Epoch 48/80
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step - loss: 0.0955 - psnr_metric: 22.1991 - ssim_metric: 0.8492
# Epoch 48: val_psnr_metric did not improve from 25.19601
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 180s 387ms/step - loss: 0.0955 - psnr_metric: 22.1992 - ssim_metric: 0.8492 - val_loss: 0.0732 - val_psnr_metric: 24.5542 - val_ssim_metric: 0.8847 - learning_rate: 4.3980e-05
# Epoch 49/80
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step - loss: 0.0961 - psnr_metric: 22.4010 - ssim_metric: 0.8476
# Epoch 49: val_psnr_metric improved from 25.19601 to 25.30747, saving model to best_low_light_model.keras
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 182s 390ms/step - loss: 0.0961 - psnr_metric: 22.4011 - ssim_metric: 0.8476 - val_loss: 0.0727 - val_psnr_metric: 25.3075 - val_ssim_metric: 0.8855 - learning_rate: 3.5184e-05
# Epoch 50/80
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step - loss: 0.0976 - psnr_metric: 22.3413 - ssim_metric: 0.8451
# Epoch 50: val_psnr_metric did not improve from 25.30747
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 179s 384ms/step - loss: 0.0976 - psnr_metric: 22.3415 - ssim_metric: 0.8451 - val_loss: 0.0732 - val_psnr_metric: 25.1053 - val_ssim_metric: 0.8847 - learning_rate: 3.5184e-05
# Epoch 51/80
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step - loss: 0.0984 - psnr_metric: 22.4059 - ssim_metric: 0.8444
# Epoch 51: val_psnr_metric did not improve from 25.30747
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 179s 383ms/step - loss: 0.0984 - psnr_metric: 22.4055 - ssim_metric: 0.8444 - val_loss: 0.0724 - val_psnr_metric: 24.8760 - val_ssim_metric: 0.8859 - learning_rate: 3.5184e-05
# Epoch 52/80
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - loss: 0.0997 - psnr_metric: 22.2311 - ssim_metric: 0.8422
# Epoch 52: val_psnr_metric did not improve from 25.30747
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 180s 385ms/step - loss: 0.0997 - psnr_metric: 22.2311 - ssim_metric: 0.8422 - val_loss: 0.0725 - val_psnr_metric: 24.8086 - val_ssim_metric: 0.8856 - learning_rate: 3.5184e-05
# Epoch 53/80
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - loss: 0.0940 - psnr_metric: 22.5193 - ssim_metric: 0.8513
# Epoch 53: val_psnr_metric did not improve from 25.30747
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 179s 385ms/step - loss: 0.0940 - psnr_metric: 22.5190 - ssim_metric: 0.8513 - val_loss: 0.0728 - val_psnr_metric: 24.1019 - val_ssim_metric: 0.8853 - learning_rate: 3.5184e-05
# Epoch 54/80
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - loss: 0.0962 - psnr_metric: 22.5164 - ssim_metric: 0.8476
# Epoch 54: val_psnr_metric did not improve from 25.30747
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 180s 386ms/step - loss: 0.0962 - psnr_metric: 22.5162 - ssim_metric: 0.8476 - val_loss: 0.0721 - val_psnr_metric: 24.6603 - val_ssim_metric: 0.8864 - learning_rate: 3.5184e-05
# Epoch 55/80
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - loss: 0.0938 - psnr_metric: 22.5923 - ssim_metric: 0.8512
# Epoch 55: val_psnr_metric did not improve from 25.30747
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 179s 385ms/step - loss: 0.0938 - psnr_metric: 22.5919 - ssim_metric: 0.8512 - val_loss: 0.0737 - val_psnr_metric: 24.1947 - val_ssim_metric: 0.8839 - learning_rate: 3.5184e-05
# Epoch 56/80
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step - loss: 0.0985 - psnr_metric: 22.3083 - ssim_metric: 0.8437
# Epoch 56: val_psnr_metric did not improve from 25.30747
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 179s 384ms/step - loss: 0.0985 - psnr_metric: 22.3087 - ssim_metric: 0.8438 - val_loss: 0.0728 - val_psnr_metric: 25.0595 - val_ssim_metric: 0.8853 - learning_rate: 3.5184e-05
# Epoch 57/80
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step - loss: 0.0964 - psnr_metric: 22.4719 - ssim_metric: 0.8477
# Epoch 57: val_psnr_metric did not improve from 25.30747
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 179s 384ms/step - loss: 0.0964 - psnr_metric: 22.4725 - ssim_metric: 0.8477 - val_loss: 0.0732 - val_psnr_metric: 24.9874 - val_ssim_metric: 0.8846 - learning_rate: 2.8147e-05
# Epoch 58/80
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step - loss: 0.0954 - psnr_metric: 22.6689 - ssim_metric: 0.8485
# Epoch 58: val_psnr_metric did not improve from 25.30747
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 179s 384ms/step - loss: 0.0954 - psnr_metric: 22.6689 - ssim_metric: 0.8485 - val_loss: 0.0722 - val_psnr_metric: 25.0985 - val_ssim_metric: 0.8863 - learning_rate: 2.8147e-05
# Epoch 59/80
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - loss: 0.0924 - psnr_metric: 22.5579 - ssim_metric: 0.8535
# Epoch 59: val_psnr_metric did not improve from 25.30747
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 179s 384ms/step - loss: 0.0924 - psnr_metric: 22.5578 - ssim_metric: 0.8535 - val_loss: 0.0720 - val_psnr_metric: 25.0321 - val_ssim_metric: 0.8866 - learning_rate: 2.8147e-05
# Epoch 60/80
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step - loss: 0.0928 - psnr_metric: 22.6999 - ssim_metric: 0.8529
# Epoch 60: val_psnr_metric did not improve from 25.30747
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 179s 383ms/step - loss: 0.0928 - psnr_metric: 22.6999 - ssim_metric: 0.8529 - val_loss: 0.0722 - val_psnr_metric: 24.8630 - val_ssim_metric: 0.8864 - learning_rate: 2.8147e-05
# Epoch 61/80
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step - loss: 0.0893 - psnr_metric: 22.6360 - ssim_metric: 0.8587
# Epoch 61: val_psnr_metric did not improve from 25.30747
# 466/466 ━━━━━━━━━━━━━━━━━━━━ 179s 384ms/step - loss: 0.0894 - psnr_metric: 22.6358 - ssim_metric: 0.8586 - val_loss: 0.0735 - val_psnr_metric: 24.3933 - val_ssim_metric: 0.8844 - learning_rate: 2.8147e-05
# Epoch 61: early stopping
# Restoring model weights from the end of the best epoch: 49.

# %%
model.save('/kaggle/working/denoisinsg_model.keras')
print("done")
# Out:
# done
